# %% [markdown]
# ## Variations in Merging FEMA data set and QWI data set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fema = pd.read_csv("https://www.dropbox.com/s/kbm13534z7sef5c/clean_fema_data?dl=1")
qwi = pd.read_csv("https://www.dropbox.com/s/nr6jxc4f6ux147n/master_qwi_2003_2018.csv?dl=1")
# ndr = natural disaster report
ndr = pd.read_csv("../../project4/dsi_project4/natural_disaster_2008_2017.csv")

# %%
fema.head()
# Out:
#    Unnamed: 0  Disaster Number IH Program Declared IA Program Declared  \
# 0           0           4411.0                  No                  No
# 1           1           4411.0                  No                  No
# 2           2           4411.0                  No                  No
# 3           3           4411.0                  No                  No
# 4           4           4411.0                  No                  No
#
#   PA Program Declared HM Program Declared State  Declaration Date  \
# 0                 Yes                 Yes     VA       12/18/2018
# 1                 Yes                 Yes     VA       12/18/2018
# 2                 Yes                 Yes     VA       12/18/2018
# 3                 Yes                 Yes     VA       12/18/2018
# 4                 Yes                 Yes     VA       12/18/2018
#
#   Disaster Type Incident Type                   Title Incident Begin Date  \
# ...

# %%
ndr.head()
# Out:
#   ISO3         Name  Year  Start Date Event Name  Hazard Category  \
# 0  AFG  Afghanistan  2008  2008-04-17        NaN      Geophysical
# 1  AFG  Afghanistan  2008  2008-08-01        NaN  Weather related
# 2  AFG  Afghanistan  2008  2008-01-01        NaN  Weather related
# 3  AFG  Afghanistan  2009  2009-01-01        NaN  Weather related
# 4  AFG  Afghanistan  2009  2009-01-01        NaN  Weather related
#
#            Hazard Type  New Displacements
# 0           Earthquake             3250.0
# 1                Flood              180.0
# 2  Extreme temperature                NaN
# 3    Wet mass movement                NaN
# 4                Flood            25185.0

# %%
ndr= ndr.loc[ndr["ISO3"] == "USA"]

# %%
ndr.head()
# Out:
#      ISO3           Name  Year  Start Date Event Name  Hazard Category  \
# 4337  USA  United States  2008  2008-06-01        NaN  Weather related
# 4338  USA  United States  2008  2008-04-01        NaN  Weather related
# 4339  USA  United States  2008  2008-11-13        NaN  Weather related
# 4340  USA  United States  2008  2008-06-20        NaN  Weather related
# 4341  USA  United States  2008  2008-12-26        NaN  Weather related
#
#      Hazard Type  New Displacements
# 4337       Flood            11000.0
# 4338       Storm            38000.0
# 4339    Wildfire            50000.0
# 4340    Wildfire              300.0
# 4341       Flood              473.0

# %%
ndr.isnull().sum()
# Out:
# ISO3                  0
# Name                  0
# Year                  0
# Start Date            0
# Event Name           61
# Hazard Category       1
# Hazard Type           1
# New Displacements    36
# dtype: int64

# %%
ndr["Year"].value_counts()
# Out:
# 2017    67
# 2015    47
# 2014    44
# 2016    43
# 2013    24
# 2011    20
# 2012    18
# 2010    11
# 2009    11
# 2008     8
# Name: Year, dtype: int64

# %%
# dropping unnamed column 
fema.drop(columns="Unnamed: 0", inplace=True)

# %%
qwi.drop(columns="Unnamed: 0", inplace=True)

# %%
fema.head()
# Out:
#    Disaster Number IH Program Declared IA Program Declared  \
# 0           4411.0                  No                  No
# 1           4411.0                  No                  No
# 2           4411.0                  No                  No
# 3           4411.0                  No                  No
# 4           4411.0                  No                  No
#
#   PA Program Declared HM Program Declared State  Declaration Date  \
# 0                 Yes                 Yes     VA       12/18/2018
# 1                 Yes                 Yes     VA       12/18/2018
# 2                 Yes                 Yes     VA       12/18/2018
# 3                 Yes                 Yes     VA       12/18/2018
# 4                 Yes                 Yes     VA       12/18/2018
#
#   Disaster Type Incident Type                   Title Incident Begin Date  \
# 0            DR     Hurricane  TROPICAL STORM MICHAEL          2018-10-09
# ...

# %%
fema.head()
# Out:
#    Disaster Number IH Program Declared IA Program Declared  \
# 0           4411.0                  No                  No
# 1           4411.0                  No                  No
# 2           4411.0                  No                  No
# 3           4411.0                  No                  No
# 4           4411.0                  No                  No
#
#   PA Program Declared HM Program Declared State  Declaration Date  \
# 0                 Yes                 Yes     VA       12/18/2018
# 1                 Yes                 Yes     VA       12/18/2018
# 2                 Yes                 Yes     VA       12/18/2018
# 3                 Yes                 Yes     VA       12/18/2018
# 4                 Yes                 Yes     VA       12/18/2018
#
#   Disaster Type Incident Type                   Title Incident Begin Date  \
# 0            DR     Hurricane  TROPICAL STORM MICHAEL          2018-10-09
# ...

# %%
fema["Incident Type"].value_counts()
# Out:
# Severe Storm(s)     16087
# Hurricane           10104
# Flood                9598
# Snow                 3658
# Fire                 2664
# Severe Ice Storm     1990
# Tornado              1417
# Drought              1289
# Coastal Storm         471
# Freezing              301
# Other                 289
# Typhoon               122
# Earthquake            105
# Volcano                50
# Fishing Losses         42
# Mud/Landslide          31
# Tsunami                 9
# Chemical                9
# Toxic Substances        7
# Human Cause             6
# Dam/Levee Break         5
# Terrorist               5
# Name: Incident Type, dtype: int64

# %%
fema.dtypes
# Out:
# Disaster Number               float64
# IH Program Declared            object
# IA Program Declared            object
# PA Program Declared            object
# HM Program Declared            object
# State                          object
# Declaration Date               object
# Disaster Type                  object
# Incident Type                  object
# Title                          object
# Incident Begin Date            object
# Incident End Date              object
# Place Code                    float64
# Declared County/Area           object
# Declaration Request Number    float64
# Incident Duration Days         object
# time                           object
# dtype: object

# %%
qwi.head()
# Out:
#    EarnBeg  EarnHirAS  EarnHirNS    EarnS  EarnSepS    Emp  EmpEnd   EmpS  \
# 0   1744.0        NaN        NaN   1744.0       NaN    NaN     NaN    NaN
# 1  14499.0        NaN        NaN  16262.0    4647.0   14.0    11.0   11.0
# 2   1863.0     1455.0     1672.0   2134.0    1966.0  133.0   139.0  103.0
# 3   4917.0     8740.0        NaN   8740.0    8740.0    NaN     NaN    NaN
# 4   3234.0        NaN        NaN   3234.0       NaN    NaN     NaN    NaN
#
#    EmpSpv  EmpTotal   ...     HirAEndReplr  HirAs  Payroll  Unnamed: 0.1  \
# 0     NaN       NaN   ...              NaN    0.0     5370           NaN
# 1    13.0      14.0   ...            0.000    0.0   570042           NaN
# 2   109.0     180.0   ...            0.154   12.0   875806           NaN
# 3     NaN       NaN   ...              NaN    NaN    89678           NaN
# 4     NaN       NaN   ...              NaN    0.0     9955           NaN
#
#    county  county_codes                 county_name  state  state_abv     time
# ...

# %%
fema.shape
# Out:
# (48259, 17)

# %%
qwi.shape
# Out:
# (189372, 30)

# %%
qwi["county_name"].value_counts()
# Out:
# Washington County           1807
# Jefferson County            1507
# Franklin County             1419
# Lincoln County              1386
# Jackson County              1381
# Madison County              1145
# Montgomery County           1084
# Clay County                 1082
# Marion County               1025
# Monroe County               1023
# Union County                1021
# Wayne County                 962
# Grant County                 843
# Greene County                842
# Warren County                841
# Carroll County               783
# Johnson County               725
# Polk County                  723
# Lee County                   723
# Adams County                 723
# Clark County                 721
# Douglas County               720
# Marshall County              720
# Lake County                  718
# Calhoun County               664
# Crawford County              663
# Fayette County               663
# Morgan County                662
# ...

# %%
qwi.isnull().sum()
# Out:
# EarnBeg            197
# EarnHirAS         3716
# EarnHirNS         4372
# EarnS             3399
# EarnSepS          6735
# Emp                358
# EmpEnd            3393
# EmpS              3480
# EmpSpv             446
# EmpTotal           305
# FrmJbC            3549
# FrmJbCS           3615
# FrmJbGn           3549
# FrmJbGnS          3615
# FrmJbLs           3549
# FrmJbLsS          3615
# HirA               360
# HirAEnd           3519
# HirAEndR          3589
# HirAEndRepl       3554
# HirAEndReplr      3592
# HirAs             3687
# Payroll              0
# Unnamed: 0.1    170232
# county               0
# county_codes         0
# county_name          0
# state                0
# state_abv            0
# time                 0
# dtype: int64

# %%
# converting time column to date time and align it as axis
fema["time"] = pd.to_datetime(fema['Incident Begin Date'])
qwi["time"] = pd.to_datetime(qwi['time'])

# %%
fema.dtypes
# Out:
# Disaster Number                      float64
# IH Program Declared                   object
# IA Program Declared                   object
# PA Program Declared                   object
# HM Program Declared                   object
# State                                 object
# Declaration Date                      object
# Disaster Type                         object
# Incident Type                         object
# Title                                 object
# Incident Begin Date                   object
# Incident End Date                     object
# Place Code                           float64
# Declared County/Area                  object
# Declaration Request Number           float64
# Incident Duration Days                object
# time                          datetime64[ns]
# dtype: object

# %%
qwi.dtypes
# Out:
# EarnBeg                float64
# EarnHirAS              float64
# EarnHirNS              float64
# EarnS                  float64
# EarnSepS               float64
# Emp                    float64
# EmpEnd                 float64
# EmpS                   float64
# EmpSpv                 float64
# EmpTotal               float64
# FrmJbC                 float64
# FrmJbCS                float64
# FrmJbGn                float64
# FrmJbGnS               float64
# FrmJbLs                float64
# FrmJbLsS               float64
# HirA                   float64
# HirAEnd                float64
# HirAEndR               float64
# HirAEndRepl            float64
# HirAEndReplr           float64
# HirAs                  float64
# Payroll                  int64
# Unnamed: 0.1           float64
# county                   int64
# county_codes            object
# county_name             object
# state                    int64
# state_abv               object
# time            datetime64[ns]
# ...

# %%
mask = (fema['time'] > '2003-1-1')

# %%
fema.loc[mask]
# Out:
#        Disaster Number IH Program Declared IA Program Declared  \
# 0               4411.0                  No                  No
# 1               4411.0                  No                  No
# 2               4411.0                  No                  No
# 3               4411.0                  No                  No
# 4               4411.0                  No                  No
# 5               4411.0                  No                  No
# 6               4411.0                  No                  No
# 7               4411.0                  No                  No
# 8               4411.0                  No                  No
# 9               4411.0                  No                  No
# 10              4411.0                  No                  No
# 11              4411.0                  No                  No
# 12              4411.0                  No                  No
# 13              4411.0                  No                  No
# ...

# %%
fema = fema.loc[mask]

# %%
fema["time"].value_counts(ascending=True)
# Out:
# 2006-08-14       1
# 2003-07-17       1
# 2009-05-18       1
# 2008-03-03       1
# 2015-05-13       1
# 2009-05-05       1
# 2008-06-25       1
# 2007-08-12       1
# 2004-06-18       1
# 2005-11-18       1
# 2009-08-29       1
# 2011-08-04       1
# 2008-06-10       1
# 2005-04-17       1
# 2004-06-05       1
# 2013-05-25       1
# 2012-09-11       1
# 2010-09-09       1
# 2003-09-02       1
# 2007-05-31       1
# 2006-03-01       1
# 2003-01-06       1
# 2004-09-28       1
# 2018-05-05       1
# 2007-06-24       1
# 2011-03-07       1
# 2009-09-22       1
# 2006-05-15       1
# 2011-07-11       1
# 2007-09-20       1
#               ...
# 2008-08-27     125
# 2011-04-06     126
# 2010-01-28     127
# 2011-08-21     134
# 2017-09-04     141
# 2008-09-07     143
# 2004-09-03     150
# 2017-09-17     156
# 2007-01-12     164
# 2005-08-27     170
# 2015-05-04     172
# 2012-08-26     180
# 2004-09-13     185
# 2003-09-18     187
# 2014-02-10     204
# 2007-12-06     207
# ...

# %%
fema["State "].value_counts()
# Out:
# TX    2368
# MO    1557
# OK    1268
# KY    1131
# GA    1068
# KS     947
# VA     879
# FL     836
# LA     824
# IA     779
# NE     746
# AL     723
# IN     689
# NY     669
# AR     663
# WV     645
# NC     629
# OH     614
# PR     605
# MS     595
# PA     583
# TN     533
# SC     497
# ND     460
# SD     460
# CA     453
# MN     437
# IL     426
# WA     298
# NJ     264
# WI     258
# MD     232
# MA     224
# MT     203
# CO     201
# NM     187
# OR     183
# NH     172
# ME     171
# MI     162
# VT     145
# CT     134
# NV     111
# AZ     105
# ID     102
# UT      81
# AK      80
# RI      53
# HI      44
# WY      37
# AS      30
# VI      29
# DE      27
# MP      26
# DC      13
# FM       4
# GU       4
# Name: State , dtype: int64

# %%
fema_tx = fema.loc[fema["State "] == "TX"]

# %%
fema_tx
# Out:
#        Disaster Number IH Program Declared IA Program Declared  \
# 487             4377.0                 Yes                  No
# 488             4377.0                 Yes                  No
# 489             4377.0                 Yes                  No
# 1798            4332.0                 Yes                  No
# 1799            4332.0                 Yes                  No
# 1800            4332.0                 Yes                  No
# 1801            4332.0                 Yes                  No
# 1802            4332.0                 Yes                  No
# 1803            4332.0                 Yes                  No
# 1804            4332.0                 Yes                  No
# 1805            4332.0                 Yes                  No
# 1806            4332.0                 Yes                  No
# 1807            4332.0                 Yes                  No
# 1808            4332.0                 Yes                  No
# ...

# %%
fema_fl = fema.loc[fema["State "] == "FL"]

# %%
fema_fl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 836 entries, 212 to 25176
# Data columns (total 17 columns):
# Disaster Number               836 non-null float64
# IH Program Declared           836 non-null object
# IA Program Declared           836 non-null object
# PA Program Declared           836 non-null object
# HM Program Declared           836 non-null object
# State                         836 non-null object
# Declaration Date              836 non-null object
# Disaster Type                 836 non-null object
# Incident Type                 836 non-null object
# Title                         836 non-null object
# Incident Begin Date           836 non-null object
# Incident End Date             812 non-null object
# Place Code                    836 non-null float64
# Declared County/Area          836 non-null object
# Declaration Request Number    836 non-null float64
# Incident Duration Days        812 non-null object
# ...

# %%
qwi.head()
# Out:
#    EarnBeg  EarnHirAS  EarnHirNS    EarnS  EarnSepS    Emp  EmpEnd   EmpS  \
# 0   1744.0        NaN        NaN   1744.0       NaN    NaN     NaN    NaN
# 1  14499.0        NaN        NaN  16262.0    4647.0   14.0    11.0   11.0
# 2   1863.0     1455.0     1672.0   2134.0    1966.0  133.0   139.0  103.0
# 3   4917.0     8740.0        NaN   8740.0    8740.0    NaN     NaN    NaN
# 4   3234.0        NaN        NaN   3234.0       NaN    NaN     NaN    NaN
#
#    EmpSpv  EmpTotal    ...      HirAEndReplr  HirAs  Payroll  Unnamed: 0.1  \
# 0     NaN       NaN    ...               NaN    0.0     5370           NaN
# 1    13.0      14.0    ...             0.000    0.0   570042           NaN
# 2   109.0     180.0    ...             0.154   12.0   875806           NaN
# 3     NaN       NaN    ...               NaN    NaN    89678           NaN
# 4     NaN       NaN    ...               NaN    0.0     9955           NaN
#
# ...

# %%
qwi_tx = qwi.loc[qwi["state_abv"] == "TX"]
qwi_fl = qwi.loc[qwi["state_abv"] == "FL"]

# %%
qwi_tx["county_name"].value_counts()
# Out:
# Anderson County        120
# Upton County            60
# Grayson County          60
# Orange County           60
# Jeff Davis County       60
# McMullen County         60
# Freestone County        60
# Potter County           60
# Hockley County          60
# Caldwell County         60
# Navarro County          60
# Mason County            60
# Lampasas County         60
# Bailey County           60
# Nacogdoches County      60
# Walker County           60
# Liberty County          60
# Hardeman County         60
# Hamilton County         60
# Karnes County           60
# Colorado County         60
# Lavaca County           60
# Culberson County        60
# Washington County       60
# Carson County           60
# Marion County           60
# Rockwall County         60
# San Saba County         60
# Ward County             60
# Young County            60
#                       ...
# Swisher County          60
# Hopkins County          60
# Lubbock County          60
# ...

# %%
import re

# %%
fema_tx["Declared County/Area"]=fema_tx["Declared County/Area"].str.replace(r"[()]","")
# Out:
# C:\Users\Trisarah\Anaconda3\envs\dsi\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
fema_tx.head()
# Out:
#       Disaster Number IH Program Declared IA Program Declared  \
# 487            4377.0                 Yes                  No
# 488            4377.0                 Yes                  No
# 489            4377.0                 Yes                  No
# 1798           4332.0                 Yes                  No
# 1799           4332.0                 Yes                  No
#
#      PA Program Declared HM Program Declared State  Declaration Date  \
# 487                   No                 Yes     TX         7/6/2018
# 488                   No                 Yes     TX         7/6/2018
# 489                   No                 Yes     TX         7/6/2018
# 1798                 Yes                 Yes     TX        8/25/2017
# 1799                 Yes                 Yes     TX        8/25/2017
#
#      Disaster Type Incident Type                       Title  \
# 487             DR         Flood  SEVERE STORMS AND FLOODING
# ...

# %%
qwi_tx.head()
# Out:
#         EarnBeg  EarnHirAS  EarnHirNS   EarnS  EarnSepS      Emp   EmpEnd  \
# 174072   2229.0     1563.0     1571.0  2389.0    1597.0  15451.0  15651.0
# 174073   2154.0     1630.0     1628.0  2317.0    1692.0  16070.0  16330.0
# 174074   2183.0     1641.0     1627.0  2388.0    1749.0  15813.0  15805.0
# 174075   2285.0     1686.0     1700.0  2459.0    1669.0  16034.0  16046.0
# 174076   2206.0     1556.0     1541.0  2361.0    1836.0  15648.0  15851.0
#
#            EmpS   EmpSpv  EmpTotal    ...      HirAEndReplr   HirAs  \
# 174072  13807.0  13695.0   18256.0    ...             0.073  1190.0
# 174073  14182.0  14212.0   19381.0    ...             0.085  1232.0
# 174074  13666.0  13751.0   19084.0    ...             0.095  1228.0
# 174075  14135.0  13902.0   19000.0    ...             0.079  1439.0
# 174076  13912.0  13854.0   18473.0    ...             0.081  1202.0
#
#           Payroll  Unnamed: 0.1  county  county_codes      county_name  state  \
# ...

# %%
fema_tx.head()
# Out:
#       Disaster Number IH Program Declared IA Program Declared  \
# 487            4377.0                 Yes                  No
# 488            4377.0                 Yes                  No
# 489            4377.0                 Yes                  No
# 1798           4332.0                 Yes                  No
# 1799           4332.0                 Yes                  No
#
#      PA Program Declared HM Program Declared State  Declaration Date  \
# 487                   No                 Yes     TX         7/6/2018
# 488                   No                 Yes     TX         7/6/2018
# 489                   No                 Yes     TX         7/6/2018
# 1798                 Yes                 Yes     TX        8/25/2017
# 1799                 Yes                 Yes     TX        8/25/2017
#
#      Disaster Type Incident Type                       Title  \
# 487             DR         Flood  SEVERE STORMS AND FLOODING
# ...

# %%
qwi_tx.dtypes
# Out:
# EarnBeg                float64
# EarnHirAS              float64
# EarnHirNS              float64
# EarnS                  float64
# EarnSepS               float64
# Emp                    float64
# EmpEnd                 float64
# EmpS                   float64
# EmpSpv                 float64
# EmpTotal               float64
# FrmJbC                 float64
# FrmJbCS                float64
# FrmJbGn                float64
# FrmJbGnS               float64
# FrmJbLs                float64
# FrmJbLsS               float64
# HirA                   float64
# HirAEnd                float64
# HirAEndR               float64
# HirAEndRepl            float64
# HirAEndReplr           float64
# HirAs                  float64
# Payroll                  int64
# Unnamed: 0.1           float64
# county                   int64
# county_codes            object
# county_name             object
# state                    int64
# state_abv               object
# time            datetime64[ns]
# ...

# %%
fema_tx.head()
# Out:
#       Disaster Number IH Program Declared IA Program Declared  \
# 487            4377.0                 Yes                  No
# 488            4377.0                 Yes                  No
# 489            4377.0                 Yes                  No
# 1798           4332.0                 Yes                  No
# 1799           4332.0                 Yes                  No
#
#      PA Program Declared HM Program Declared State  Declaration Date  \
# 487                   No                 Yes     TX         7/6/2018
# 488                   No                 Yes     TX         7/6/2018
# 489                   No                 Yes     TX         7/6/2018
# 1798                 Yes                 Yes     TX        8/25/2017
# 1799                 Yes                 Yes     TX        8/25/2017
#
#      Disaster Type Incident Type                       Title  \
# 487             DR         Flood  SEVERE STORMS AND FLOODING
# ...

# %%
fema_tx.set_index(pd.to_datetime(fema_tx["time"]), inplace=True)
qwi_tx.set_index(pd.to_datetime(qwi_tx["time"]), inplace=True)

# %%
tx_data = pd.merge(fema_tx, qwi_tx, how="outer", left_index=True, right_index=True)

# %%
tx_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17921 entries, 2003-01-01 to 2018-06-19
# Data columns (total 47 columns):
# Disaster Number               2876 non-null float64
# IH Program Declared           2876 non-null object
# IA Program Declared           2876 non-null object
# PA Program Declared           2876 non-null object
# HM Program Declared           2876 non-null object
# State                         2876 non-null object
# Declaration Date              2876 non-null object
# Disaster Type                 2876 non-null object
# Incident Type                 2876 non-null object
# Title                         2876 non-null object
# Incident Begin Date           2876 non-null object
# Incident End Date             2337 non-null object
# Place Code                    2876 non-null float64
# Declared County/Area          2876 non-null object
# Declaration Request Number    2876 non-null float64
# Incident Duration Days        2337 non-null object
# ...

# %%
tx_data = fema_tx.merge(qwi_tx, left_index=True, right_index=True)

# %%
#fema_pop = pd.read_csv("../../project4/dsi_project4/fema_pop.csv")

# %%
fema_pop.head()
# Out:
#    Unnamed: 0  SUMLEV  STATE  COUNTY   STNAME  CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0           0      50      1       1  Alabama  Autauga     1       0    54571
# 1           1      50      1       1  Alabama  Autauga     1       0    54571
# 2           2      50      1       1  Alabama  Autauga     1       0    54571
# 3           3      50      1       1  Alabama  Autauga     1       0    54571
# 4           4      50      1       1  Alabama  Autauga     1       0    54571
#
#    TOT_MALE              ...               Disaster Type    Incident Type  \
# 0     26569              ...                          DR        Hurricane
# 1     26569              ...                          EM        Hurricane
# 2     26569              ...                          EM        Hurricane
# 3     26569              ...                          DR  Severe Storm(s)
# 4     26569              ...                          DR  Severe Storm(s)
#
# ...

# %%
fema_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8404840 entries, 0 to 8404839
# Data columns (total 99 columns):
# Unnamed: 0                      int64
# SUMLEV                          int64
# STATE                           int64
# COUNTY                          int64
# STNAME                          object
# CTYNAME                         object
# YEAR                            int64
# AGEGRP                          int64
# TOT_POP                         int64
# TOT_MALE                        int64
# TOT_FEMALE                      int64
# WA_MALE                         int64
# WA_FEMALE                       int64
# BA_MALE                         int64
# BA_FEMALE                       int64
# IA_MALE                         int64
# IA_FEMALE                       int64
# AA_MALE                         int64
# AA_FEMALE                       int64
# NA_MALE                         int64
# NA_FEMALE                       int64
# ...

# %%
fema.dtypes
# Out:
# Disaster Number                      float64
# IH Program Declared                   object
# IA Program Declared                   object
# PA Program Declared                   object
# HM Program Declared                   object
# State                                 object
# Declaration Date                      object
# Disaster Type                         object
# Incident Type                         object
# Title                                 object
# Incident Begin Date                   object
# Incident End Date                     object
# Place Code                           float64
# Declared County/Area                  object
# Declaration Request Number           float64
# Incident Duration Days                object
# time                          datetime64[ns]
# dtype: object

# %%
qwi.dtypes
# Out:
# EarnBeg                float64
# EarnHirAS              float64
# EarnHirNS              float64
# EarnS                  float64
# EarnSepS               float64
# Emp                    float64
# EmpEnd                 float64
# EmpS                   float64
# EmpSpv                 float64
# EmpTotal               float64
# FrmJbC                 float64
# FrmJbCS                float64
# FrmJbGn                float64
# FrmJbGnS               float64
# FrmJbLs                float64
# FrmJbLsS               float64
# HirA                   float64
# HirAEnd                float64
# HirAEndR               float64
# HirAEndRepl            float64
# HirAEndReplr           float64
# HirAs                  float64
# Payroll                  int64
# Unnamed: 0.1           float64
# county                   int64
# county_codes            object
# county_name             object
# state                    int64
# state_abv               object
# time            datetime64[ns]
# ...

# %%
qwi["qtime"] = pd.PeriodIndex(qwi["time"] , freq='Q')
fema["qtime"] = pd.PeriodIndex(fema["time"] , freq='Q')

# %%
qwi.dtypes
# Out:
# EarnBeg                float64
# EarnHirAS              float64
# EarnHirNS              float64
# EarnS                  float64
# EarnSepS               float64
# Emp                    float64
# EmpEnd                 float64
# EmpS                   float64
# EmpSpv                 float64
# EmpTotal               float64
# FrmJbC                 float64
# FrmJbCS                float64
# FrmJbGn                float64
# FrmJbGnS               float64
# FrmJbLs                float64
# FrmJbLsS               float64
# HirA                   float64
# HirAEnd                float64
# HirAEndR               float64
# HirAEndRepl            float64
# HirAEndReplr           float64
# HirAs                  float64
# Payroll                  int64
# Unnamed: 0.1           float64
# county                   int64
# county_codes            object
# county_name             object
# state                    int64
# state_abv               object
# time            datetime64[ns]
# ...

# %%
fema.dtypes
# Out:
# Disaster Number                      float64
# IH Program Declared                   object
# IA Program Declared                   object
# PA Program Declared                   object
# HM Program Declared                   object
# State                                 object
# Declaration Date                      object
# Disaster Type                         object
# Incident Type                         object
# Title                                 object
# Incident Begin Date                   object
# Incident End Date                     object
# Place Code                           float64
# Declared County/Area                  object
# Declaration Request Number           float64
# Incident Duration Days                object
# time                          datetime64[ns]
# qtime                                 object
# dtype: object

# %%
qwi.reset_index(level=0, inplace=True)

# %%
qwi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189372 entries, 0 to 189371
# Data columns (total 31 columns):
# county_name     189372 non-null object
# qtime           189372 non-null object
# state_abv       189372 non-null object
# EarnBeg         189175 non-null float64
# EarnHirAS       185656 non-null float64
# EarnHirNS       185000 non-null float64
# EarnS           185973 non-null float64
# EarnSepS        182637 non-null float64
# Emp             189014 non-null float64
# EmpEnd          185979 non-null float64
# EmpS            185892 non-null float64
# EmpSpv          188926 non-null float64
# EmpTotal        189067 non-null float64
# FrmJbC          185823 non-null float64
# FrmJbCS         185757 non-null float64
# FrmJbGn         185823 non-null float64
# FrmJbGnS        185757 non-null float64
# FrmJbLs         185823 non-null float64
# FrmJbLsS        185757 non-null float64
# HirA            189012 non-null float64
# HirAEnd         185853 non-null float64
# ...

# %%
fema.reset_index(level=0, inplace=True)

# %%
fema.head()
# Out:
#    qtime state_abv               county  Disaster Number IH Program Declared  \
# 0 2018Q4        VA             Danville           4411.0                  No
# 1 2018Q4        VA                Galax           4411.0                  No
# 2 2018Q4        VA      Amelia (County)           4411.0                  No
# 3 2018Q4        VA  Appomattox (County)           4411.0                  No
# 4 2018Q4        VA   Brunswick (County)           4411.0                  No
#
#   IA Program Declared PA Program Declared HM Program Declared  \
# 0                  No                 Yes                 Yes
# 1                  No                 Yes                 Yes
# 2                  No                 Yes                 Yes
# 3                  No                 Yes                 Yes
# 4                  No                 Yes                 Yes
#
#   Declaration Date Disaster Type Incident Type                   Title  \
# ...

# %%
qwi.head()
# Out:
#    qtime  county state_abv                 county_name  EarnBeg  EarnHirAS  \
# 0 2003Q1      13        AK      Aleutians East Borough   1744.0        NaN
# 1 2003Q1      16        AK  Aleutians West Census Area  14499.0        NaN
# 2 2003Q1      20        AK      Anchorage Municipality   1863.0     1455.0
# 3 2003Q1      50        AK          Bethel Census Area   4917.0     8740.0
# 4 2003Q1      70        AK      Dillingham Census Area   3234.0        NaN
#
#    EarnHirNS    EarnS  EarnSepS    Emp    ...      HirAEnd  HirAEndR  \
# 0        NaN   1744.0       NaN    NaN    ...          NaN       NaN
# 1        NaN  16262.0    4647.0   14.0    ...          0.0     0.000
# 2     1672.0   2134.0    1966.0  133.0    ...         36.0     0.265
# 3        NaN   8740.0    8740.0    NaN    ...          NaN       NaN
# 4        NaN   3234.0       NaN    NaN    ...          NaN       NaN
#
#    HirAEndRepl  HirAEndReplr  HirAs  Payroll  Unnamed: 0.1  county_codes  \
# ...

# %%
fema.rename(columns={"county":"county_name"}, inplace=True)

# %%
fema.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25664 entries, 0 to 25663
# Data columns (total 18 columns):
# qtime                         25664 non-null object
# state_abv                     25664 non-null object
# county_name                   25664 non-null object
# Disaster Number               25664 non-null float64
# IH Program Declared           25664 non-null object
# IA Program Declared           25664 non-null object
# PA Program Declared           25664 non-null object
# HM Program Declared           25664 non-null object
# Declaration Date              25664 non-null object
# Disaster Type                 25664 non-null object
# Incident Type                 25664 non-null object
# Title                         25664 non-null object
# Incident Begin Date           25664 non-null object
# Incident End Date             25513 non-null object
# Place Code                    25664 non-null float64
# Declaration Request Number    25664 non-null float64
# ...

# %%
qwi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 189372 entries, (AK, Aleutians East Borough, 2003Q1) to (TX, Zavala County, 2017Q4)
# Data columns (total 28 columns):
# county          189372 non-null int64
# EarnBeg         189175 non-null float64
# EarnHirAS       185656 non-null float64
# EarnHirNS       185000 non-null float64
# EarnS           185973 non-null float64
# EarnSepS        182637 non-null float64
# Emp             189014 non-null float64
# EmpEnd          185979 non-null float64
# EmpS            185892 non-null float64
# EmpSpv          188926 non-null float64
# EmpTotal        189067 non-null float64
# FrmJbC          185823 non-null float64
# FrmJbCS         185757 non-null float64
# FrmJbGn         185823 non-null float64
# FrmJbGnS        185757 non-null float64
# FrmJbLs         185823 non-null float64
# FrmJbLsS        185757 non-null float64
# HirA            189012 non-null float64
# HirAEnd         185853 non-null float64
# ...

# %%
fema["county_name"]=fema["county_name"].str.replace(r"[()]","")

# %%
fema.set_index(["state_abv", "county_name", "qtime"], inplace=True)

# %%
qwi.set_index(["state_abv", "county_name", "qtime"], inplace=True)

# %%
fema_qwi_data = pd.merge(qwi, fema, how="outer", left_index=True, right_index=True)

# %%
fema_qwi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 195719 entries, (AK, Alaska Gateway Regional Educational Attendance Area, 2009Q2) to (WY, Wind River Indian Reservation, 2011Q2)
# Data columns (total 43 columns):
# county                        193457 non-null float64
# EarnBeg                       193260 non-null float64
# EarnHirAS                     189737 non-null float64
# EarnHirNS                     189081 non-null float64
# EarnS                         190054 non-null float64
# EarnSepS                      186468 non-null float64
# Emp                           193099 non-null float64
# EmpEnd                        190060 non-null float64
# EmpS                          189973 non-null float64
# EmpSpv                        193011 non-null float64
# EmpTotal                      193152 non-null float64
# FrmJbC                        189904 non-null float64
# FrmJbCS                       189838 non-null float64
# ...

# %%
fema_qwi_data.reset_index(inplace=True)

# %%
fema_qwi_data.head()
# Out:
#   state_abv                                        county_name  qtime  county  \
# 0        AK  Alaska Gateway Regional Educational Attendance... 2009Q2     NaN
# 1        AK  Alaska Gateway Regional Educational Attendance... 2012Q3     NaN
# 2        AK  Alaska Gateway Regional Educational Attendance... 2013Q2     NaN
# 3        AK                             Aleutians East Borough 2003Q1    13.0
# 4        AK                             Aleutians East Borough 2003Q1    13.0
#
#    EarnBeg  EarnHirAS  EarnHirNS   EarnS  EarnSepS    Emp    ...      \
# 0      NaN        NaN        NaN     NaN       NaN    NaN    ...
# 1      NaN        NaN        NaN     NaN       NaN    NaN    ...
# 2      NaN        NaN        NaN     NaN       NaN    NaN    ...
# 3   1744.0        NaN        NaN  1744.0       NaN    NaN    ...
# 4   2210.0     1293.0     1443.0  2307.0    1775.0  744.0    ...
#
#    Declaration Date  Disaster Type    Incident Type  \
# ...

# %%
fema_qwi_data.to_csv("fema_qwi_data")
