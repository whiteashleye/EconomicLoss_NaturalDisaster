# %%
import pandas as pd
import glob

# %%
# qwi = pd.concat([pd.read_csv(f) for f in glob.glob('./qwi/*.csv')], ignore_index = True)
# qwi.to_csv('./qwi_aggregated.csv')

# %%
#glassdoor_2018 = pd.concat([pd.read_csv(f) for f in glob.glob('../project-4/data/glassdoor_csvs/*.csv')], ignore_index = True)
#glassdoor_2018.to_csv('./glassdoor_2018.csv')

# %%
# Read in datasets:

# %%
# County Business Patterns (as of 2016)
cbp = pd.read_csv('https://www.dropbox.com/s/sxjp0ghsq61k5gr/cbp16co.txt?dl=1')

# %%
# Quaterly Work Indicators (through Q1 2018)
qwi = pd.read_csv('https://www.dropbox.com/s/fuvc3s6d40ydc45/master_qwi_2003_2018.csv?dl=1')

# %%
# Recorded FEMA Disasters (through 2018)
fema_disaster = pd.read_csv('https://www.dropbox.com/s/csf8o84x2olw7n2/clean_fema_data?dl=1')

# %%
# US Population by County (2017)
us_pop = pd.read_csv('https://www.dropbox.com/s/mjdn983a95p2a6r/cc-est2017-alldata.csv?dl=1', encoding='latin-1')

# %%
# Glassdoor median salary by role (2017 - 2018)
glassdoor = pd.read_csv('https://www.dropbox.com/s/t9tid6bcj50zirw/glassdoor_2018.csv?dl=1')

# %%
# Monster job posts
monster = pd.read_csv('https://www.dropbox.com/s/ns4xwwygjwqppmn/monster_com-job_sample.csv?dl=1')

# %%
cbp.head()
# Out:
#    fipstate  fipscty   naics empflag emp_nf    emp qp1_nf    qp1 ap_nf  \
# 0         1        1  ------     NaN      G  10790      G  79369     G
# 1         1        1  11----     NaN      G     87      H    989     H
# 2         1        1  113///     NaN      G     83      G    952     H
# 3         1        1  1133//     NaN      G     83      G    952     H
# 4         1        1  11331/     NaN      G     83      G    952     H
#
#        ap   ...    n100_249  n250_499  n500_999  n1000  n1000_1  n1000_2  \
# 0  332497   ...           8         2         1      0        0        0
# 1    4270   ...           0         0         0      0        0        0
# 2    4061   ...           0         0         0      0        0        0
# 3    4061   ...           0         0         0      0        0        0
# 4    4061   ...           0         0         0      0        0        0
#
#    n1000_3  n1000_4  censtate  cencty
# 0        0        0        63       1
# ...

# %%
fema_disaster.head()
# Out:
#    Unnamed: 0  Disaster Number IH Program Declared IA Program Declared  \
# 0           0           4411.0                  No                  No
# 1           1           4411.0                  No                  No
# 2           2           4411.0                  No                  No
# 3           3           4411.0                  No                  No
# 4           4           4411.0                  No                  No
#
#   PA Program Declared HM Program Declared State  Declaration Date  \
# 0                 Yes                 Yes     VA       12/18/2018
# 1                 Yes                 Yes     VA       12/18/2018
# 2                 Yes                 Yes     VA       12/18/2018
# 3                 Yes                 Yes     VA       12/18/2018
# 4                 Yes                 Yes     VA       12/18/2018
#
#   Disaster Type Incident Type                   Title Incident Begin Date  \
# ...

# %%
qwi.head()
# Out:
#    Unnamed: 0  EarnBeg  EarnHirAS  EarnHirNS    EarnS  EarnSepS    Emp  \
# 0  2003-01-01   1744.0        NaN        NaN   1744.0       NaN    NaN
# 1  2003-01-01  14499.0        NaN        NaN  16262.0    4647.0   14.0
# 2  2003-01-01   1863.0     1455.0     1672.0   2134.0    1966.0  133.0
# 3  2003-01-01   4917.0     8740.0        NaN   8740.0    8740.0    NaN
# 4  2003-01-01   3234.0        NaN        NaN   3234.0       NaN    NaN
#
#    EmpEnd   EmpS  EmpSpv   ...     HirAEndReplr  HirAs  Payroll  Unnamed: 0.1  \
# 0     NaN    NaN     NaN   ...              NaN    0.0     5370           NaN
# 1    11.0   11.0    13.0   ...            0.000    0.0   570042           NaN
# 2   139.0  103.0   109.0   ...            0.154   12.0   875806           NaN
# 3     NaN    NaN     NaN   ...              NaN    NaN    89678           NaN
# 4     NaN    NaN     NaN   ...              NaN    0.0     9955           NaN
#
# ...

# %%
us_pop.head()
# Out:
#    SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0      50      1       1  Alabama  Autauga County     1       0    54571
# 1      50      1       1  Alabama  Autauga County     1       1     3579
# 2      50      1       1  Alabama  Autauga County     1       2     3991
# 3      50      1       1  Alabama  Autauga County     1       3     4290
# 4      50      1       1  Alabama  Autauga County     1       4     4290
#
#    TOT_MALE  TOT_FEMALE     ...       HWAC_MALE  HWAC_FEMALE  HBAC_MALE  \
# 0     26569       28002     ...             607          538         57
# 1      1866        1713     ...              77           56          9
# 2      2001        1990     ...              64           66          2
# 3      2171        2119     ...              51           57         13
# 4      2213        2077     ...              48           44          7
#
#    HBAC_FEMALE  HIAC_MALE  HIAC_FEMALE  HAAC_MALE  HAAC_FEMALE  HNAC_MALE  \
# ...

# %%
glassdoor.head()
# Out:
#    Unnamed: 0          Metro Dimension Type    Month         Dimension  \
# 0           0       National    Quick Facts  2018-09   U.S. Median Pay
# 1           1        Atlanta    Quick Facts  2018-09  Metro Median Pay
# 2           2        Atlanta    Quick Facts  2018-09   U.S. Median Pay
# 3           3        Atlanta    Quick Facts  2018-09      Job Openings
# 4           4  New York City    Quick Facts  2018-09  Metro Median Pay
#
#             Measure     Value     YoY
# 0   U.S. Median Pay  $52,664    2.60%
# 1  Metro Median Pay  $54,329    2.30%
# 2   U.S. Median Pay  $52,664    2.60%
# 3      Job Openings   148,874  33.30%
# 4  Metro Median Pay  $62,761    3.00%

# %%
monster.head()
# Out:
#                     country country_code date_added has_expired  \
# 0  United States of America           US        NaN          No
# 1  United States of America           US        NaN          No
# 2  United States of America           US        NaN          No
# 3  United States of America           US        NaN          No
# 4  United States of America           US        NaN          No
#
#           job_board                                    job_description  \
# 0  jobs.monster.com  TeamSoft is seeing an IT Support Specialist to...
# 1  jobs.monster.com  The Wisconsin State Journal is seeking a flexi...
# 2  jobs.monster.com  Report this job About the Job DePuy Synthes Co...
# 3  jobs.monster.com  Why Join Altec? If you’re considering a career...
# 4  jobs.monster.com  Position ID#  76162 # Positions  1 State  CT C...
#
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# ...
